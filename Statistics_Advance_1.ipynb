# %% [markdown]
# # **Statistics Advance Part 1**

# %% [markdown]
# **Q1. What is a random variable in probability theory?**

# %% [markdown]
# **Ans:-**Probability theory, a random variable is a variable that represents the outcome of a random phenomenon.

# %% [markdown]
# **Q2.What are the types of random variables?**

# %% [markdown]
# **Ans:-**1.**Discrete Random Variable**
# A discrete random variable takes on a countable number of distinct values. These could be finite or countably infinite.
#
# 2.**Continuous Random Variable**
# A continuous random variable can take on infinitely many values within a given interval. The possible values are uncountable and usually represent measurements.

# %% [markdown]
# **Q3.What is the difference between discrete and continuous distributions?**

# %% [markdown]
# **Ans:-** **Discrete Distribution**:-
# A discrete distribution describes the probability of outcomes of a discrete random variable—one that takes on countable values (like whole numbers).
#
# **Continuous Distribution**:-
# A continuous distribution describes the probability of outcomes of a continuous random variable—one that takes values in a continuous range (like real numbers over an interval).

# %% [markdown]
# **Q4.What are probability distribution functions (PDF)?**

# %% [markdown]
# **Ans:-**A Probability Distribution Function (PDF) describes how probabilities are distributed over the possible values of a random variable.

# %% [markdown]
# **Q5.How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?**

# %% [markdown]
# **Ans:-** **1.Probability Density Function (PDF**):-A Probability Density Function (PDF) describes the relative likelihood of a continuous random variable taking on a particular value.
#
# **2. Cumulative Distribution Function (CDF):-**A Cumulative Distribution Function (CDF) gives the probability that a random variable 𝑋X takes on a value less than or equal to 𝑥x.

# %% [markdown]
# **Q6.What is a discrete uniform distribution?**

# %% [markdown]
# **Ans:-**A discrete uniform distribution is a type of probability distribution in which all outcomes are equally likely over a finite set of distinct values.

# %% [markdown]
# **Q7.What are the key properties of a Bernoulli distribution?**

# %% [markdown]
# **Ans:-**The Bernoulli distribution is the simplest discrete probability distribution, representing a random experiment with exactly two outcomes: typically success (1) and failure (0).

# %% [markdown]
# **Q8.What is the binomial distribution, and how is it used in probability?**

# %% [markdown]
# **Ans:-**The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure.

# %% [markdown]
# **Q9.What is the Poisson distribution and where is it applied?**

# %% [markdown]
# **Ans:-**The Poisson distribution is a discrete probability distribution that models the number of times an event occurs in a fixed interval of time, space, or volume, given that:
#
# Events occur independently
#
# Events happen at a constant average rate
#
# Two events cannot occur at exactly the same instant

# %% [markdown]
# **Q10.What is a continuous uniform distribution?**

# %% [markdown]
# **Ans:-**A continuous uniform distribution is a probability distribution where a continuous random variable 𝑋X is equally likely to take any value within a fixed interval [𝑎,𝑏][a,b].

# %% [markdown]
# **Q11.What are the characteristics of a normal distribution?**

# %% [markdown]
# **Ans:-**The normal distribution (also called the Gaussian distribution) is one of the most important and widely used continuous probability distributions in statistics.
#
# **Characteristics:**
# **Symmetry:**The distribution is perfectly symmetric about the mean 𝜇.
# **Mean, Median, and Mode are Equal**:All three measures of central tendency coincide at 𝜇.
# **Bell-shaped Curve**:The graph of the PDF is a smooth, bell-shaped curve.
# **Asymptotic Tails**:The tails of the curve approach the x-axis but never touch it, extending infinitely in both directions.
# **Defined by Two Parameters**:
# The mean μ shifts the center, and the standard deviation σ controls the spread.
# **Skewness and Kurtosis**:
# i.Skewness = 0 (no skew, perfectly symmetrical)
# ii.Kurtosis = 3 (mesokurtic, moderate tail thickness)

# %% [markdown]
# **Q12. What is the standard normal distribution, and why is it important?**

# %% [markdown]
# **Ans:-**Standard normal distribution, also known as the z-distribution, is a special type of normal distribution. In this distribution, the mean (average) is 0 and the standard deviation (a measure of spread) is 1. This creates a bell-shaped curve that is symmetrical around the mean.

# %% [markdown]
# **Q13.What is the Central Limit Theorem (CLT), and why is it critical in statistics?**

# %% [markdown]
# **Ans:-**The Central Limit Theorem in Statistics states that as the sample size increases and its variance is finite, then the distribution of the sample mean approaches normal distribution irrespective of the shape of the population distribution.The central limit theorem posits that the distribution of sample means will invariably conform to a normal distribution provided the sample size is sufficiently large. This holds regardless of the underlying distribution of the population, be it normal, Poisson, binomial, or any alternative distribution.

# %% [markdown]
# **Q14.How does the Central Limit Theorem relate to the normal distribution?**

# %% [markdown]
# **Ans:-**The Central Limit Theorem (CLT) directly connects to the normal distribution by explaining why and how the normal distribution arises naturally in statistics.
#
# **the CLT Relates to the Normal Distribution**:
# i.The CLT states that when you take the mean of a large number of independent, identically distributed (i.i.d.) random variables, regardless of the original distribution’s shape, the distribution of these sample means approaches a normal distribution.
#
# ii.This means the normal distribution serves as the limiting distribution for sample means as the sample size 𝑛 becomes large.

# %% [markdown]
# **Q15.What is the application of Z statistics in hypothesis testing?**

# %% [markdown]
# Ans:-The Z-statistic (or Z-score) measures how many standard deviations a sample statistic (like a sample mean) is from the population mean under the null hypothesis.
#
# i.The population variance is known, or
#
# ii.The sample size is large (typically 𝑛≥30) allowing approximation of the sampling distribution to normal.

# %% [markdown]
# **Q16. How do you calculate a Z-score, and what does it represent?**

# %% [markdown]
# **Ans:-**The Z-score measures how many standard deviations a data point 𝑥 is from the mean μ of the distribution.
# **Standardized Position**:It tells you how far and in what direction the value 𝑥 is from the mean, measured in units of standard deviation.
# **Relative Standing:**A positive Z-score means 𝑥 is above the mean, a negative Z-score means it’s below the mean.
# **Comparability:**Z-scores allow you to compare values from different distributions or scales by putting them on a common scale.
# **Probability Connection:**Using the Z-score and the standard normal distribution, you can find the probability (or percentile) of observing a value less than or greater than 𝑥.

# %% [markdown]
# **Q17. What are point estimates and interval estimates in statistics?**

# %% [markdown]
# **Ans:-** **Point Estimates**:A point estimate is a single value used to estimate an unknown population parameter (like the mean, proportion, or variance).
#
# **Interval Estimates**:An interval estimate provides a range of values within which the population parameter is likely to lie, with a specified level of confidence.

# %% [markdown]
# **Q18. What is the significance of confidence intervals in statistical analysis?**

# %% [markdown]
# **Ans:-**A confidence interval (CI) is a range of values, derived from sample data, that is likely to contain the true population parameter (like the mean or proportion) with a specified level of confidence.

# %% [markdown]
# **Q19. What is the relationship between a Z-score and a confidence interval?**

# %% [markdown]
# **Ans:-**Z-scores determine the critical values that define the bounds of a confidence interval for a population parameter (usually the mean) when the population standard deviation is known or the sample size is large.

# %% [markdown]
# **Q20. How are Z-scores used to compare different distributions?**

# %% [markdown]
# **Ans:-** **1.Standardizing Different Data:**
# i.Different distributions may have different means and standard deviations.
# ii.To compare values across these different scales, you standardize each value into a Z-score
#
# **2.Meaning of the Z-Score**
# i.A Z-score tells you how many standard deviations a value is from its own distribution’s mean.
# ii.Once converted to Z-scores, values from different distributions can be directly compared because they are now on the same scale (mean 0, std dev 1).

# %% [markdown]
# **Q21. What are the assumptions for applying the Central Limit Theorem?**

# %% [markdown]
# **Ans:-** **Assumptions for the Central Limit Theorem**
#
# **1.Independence:**The sampled observations must be independent of each other. This is usually satisfied if the data come from a simple random sample or the sampling is done with replacement.
#
# **2.Identically Distributed:**The random variables (samples) should be identically distributed, meaning they come from the same population or have the same probability distribution.
#
# **3.Sample Size (Sufficiently Large):**The sample size 𝑛 should be large enough for the sample mean distribution to be approximately normal.
#
# **4.Finite Variance:**The population must have a finite variance  𝜎2. Infinite variance violates the theorem’s conditions.

# %% [markdown]
# **Q22. What is the concept of expected value in a probability distribution?**

# %% [markdown]
# **Ans:-**The expected value (also called the mean) of a random variable is the long-run average value it takes after many repetitions of the experiment or trial.

# %% [markdown]
# **Q23. How does a probability distribution relate to the expected outcome of a random variable??**

# %% [markdown]
# **Ans:-** **Relationship Between Probability Distribution and Expected Outcome**
# i.A probability distribution describes all possible values a random variable can take and their associated probabilities (discrete case) or density (continuous case).
#
# ii.The expected outcome (or expected value) is the weighted average of these possible values, where the weights are the probabilities from the distribution.

# %% [markdown]
# # ** Practical**

# %% [markdown]
# **Q1.Write a Python program to generate a random variable and display its value.**

# %%
import random

outcomes = [1, 2, 3, 4, 5, 6]

random_value = random.choice(outcomes)

print("Discrete random variable (die roll):", random_value)
# Out:
# Discrete random variable (die roll): 4

# %% [markdown]
# **Q2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution
low = 1
high = 7  # upper bound is exclusive in scipy.stats.randint

# Create the distribution
dist = randint(low, high)

# Define the values (support)
x = np.arange(low, high)

# Get the PMF values
pmf_values = dist.pmf(x)

# Plot the PMF
plt.bar(x, pmf_values, color='skyblue', edgecolor='black')
plt.title('PMF of Discrete Uniform Distribution (1 to 6)')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Q3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.**

# %%
def bernoulli_pmf(x, p):
    """
    Calculate the PMF of a Bernoulli distribution.

    Parameters:
        x (int): The outcome (0 or 1)
        p (float): The probability of success (0 ≤ p ≤ 1)

    Returns:
        float: The probability P(X = x)
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1 (inclusive).")

    return p if x == 1 else (1 - p)

# Example usage
p = 0.7  # probability of success
print("P(X=0):", bernoulli_pmf(0, p))
print("P(X=1):", bernoulli_pmf(1, p))
# Out:
# P(X=0): 0.30000000000000004
# P(X=1): 0.7

# %% [markdown]
# **Q4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
n = 10      # number of trials
p = 0.5     # probability of success
size = 10000  # number of simulations

data = np.random.binomial(n, p, size)

plt.hist(data, bins=np.arange(-0.5, n + 1.5, 1), density=True, edgecolor='black', rwidth=0.9)
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(range(n + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Q5. Create a Poisson distribution and visualize it using Python.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
λ = 4       # average rate (mean of the Poisson distribution)
size = 10000  # number of random samples

# Generate Poisson-distributed data
data = np.random.poisson(λ, size)

# Get range of values and PMF for plotting
x = np.arange(0, np.max(data) + 1)
pmf = poisson.pmf(x, mu=λ)

# Plot histogram of the simulated data
plt.hist(data, bins=np.arange(np.min(data)-0.5, np.max(data)+1.5, 1),
         density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Simulated Data')

# Overlay theoretical PMF using stem plot
plt.stem(x, pmf, linefmt='r-', markerfmt='ro', basefmt=' ', label='Theoretical PMF')

# Plot settings
plt.title(f'Poisson Distribution (λ = {λ})')
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Q6.Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.**

# %%
# Parameters of the discrete uniform distribution
a = 1  # start value
b = 6  # end value

# Possible outcomes
x = np.arange(a, b + 1)

# Since it's uniform, each outcome has equal probability
p = 1 / len(x)

# Calculate the CDF by taking cumulative sum of the PMF
pmf = np.full_like(x, p, dtype=float)
cdf = np.cumsum(pmf)

# Plotting the CDF
plt.step(x, cdf, where='post', label='CDF', color='blue')
plt.scatter(x, cdf, color='red')  # mark the CDF points
plt.title('CDF of Discrete Uniform Distribution')
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.ylim(0, 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# **Q7. Generate a continuous uniform distribution using NumPy and visualize it.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the uniform distribution
a = 0    # lower bound
b = 10   # upper bound
size = 10000  # number of samples

# Generate random samples from a continuous uniform distribution
data = np.random.uniform(low=a, high=b, size=size)

# Plot a histogram of the samples
plt.hist(data, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sample Histogram')

# Overlay the theoretical PDF (constant for uniform distribution)
plt.axhline(y=1/(b - a), color='red', linestyle='--', label='Theoretical PDF')

# Plot settings
plt.title('Continuous Uniform Distribution (U[0, 10])')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Q8. Simulate data from a normal distribution and plot its histogram.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the normal distribution
mean = 0      # μ: mean of the distribution
std_dev = 1   # σ: standard deviation
size = 10000  # number of samples

# Generate random samples from a normal distribution
data = np.random.normal(loc=mean, scale=std_dev, size=size)

# Plot the histogram
plt.hist(data, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sample Histogram')

# Plot settings
plt.title('Histogram of Normal Distribution (μ=0, σ=1)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# %% [markdown]
# **Q9.Write a Python function to calculate Z-scores from a dataset and plot them.**

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_and_plot_zscores(data):
    """
    Calculates Z-scores from a dataset and plots their histogram.

    Parameters:
        data (list or np.ndarray): The input dataset.

    Returns:
        z_scores (np.ndarray): Array of calculated Z-scores.
    """
    data = np.array(data)
    mean = np.mean(data)
    std_dev = np.std(data)

    # Calculate Z-scores
    z_scores = (data - mean) / std_dev

    # Plot histogram of Z-scores
    plt.hist(z_scores, bins=30, density=True, color='skyblue', edgecolor='black')
    plt.title('Histogram of Z-Scores')
    plt.xlabel('Z-score')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.axvline(0, color='red', linestyle='--', label='Mean (Z=0)')
    plt.legend()
    plt.show()

    return z_scores

# Example usage
if __name__ == "__main__":
    # Generate sample data from a normal distribution
    sample_data = np.random.normal(loc=100, scale=15, size=1000)
    z_scores = calculate_and_plot_zscores(sample_data)

# %% [markdown]
# **Q10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
lambda_param = 1.0             # Rate parameter for the exponential distribution
sample_size = 30               # Size of each sample
num_samples = 1000             # Number of samples to simulate

# Step 1: Generate multiple sample means from exponential distribution
sample_means = []

for _ in range(num_samples):
    sample = np.random.exponential(scale=1/lambda_param, size=sample_size)
    sample_means.append(np.mean(sample))

# Step 2: Plot histogram of the sample means
plt.hist(sample_means, bins=40, density=True, color='skyblue', edgecolor='black')
plt.title(f'Central Limit Theorem Demonstration\n(Exponential → Sample Means)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.axvline(np.mean(sample_means), color='red', linestyle='--', label='Mean of sample means')
plt.legend()
plt.show()

# %% [markdown]
# **Q11.Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters
mu = 50              # population mean
sigma = 10           # population standard deviation
sample_size = 30     # number of observations per sample
num_samples = 1000   # number of samples to simulate

# Step 1: Generate multiple samples and compute their means
sample_means = []

for _ in range(num_samples):
    sample = np.random.normal(loc=mu, scale=sigma, size=sample_size)
    sample_means.append(np.mean(sample))

sample_means = np.array(sample_means)

# Step 2: Plot histogram of the sample means
plt.hist(sample_means, bins=40, density=True, color='skyblue', edgecolor='black', alpha=0.7, label='Sample Means')

# Step 3: Overlay theoretical normal curve (CLT expected distribution)
x = np.linspace(min(sample_means), max(sample_means), 1000)
pdf = norm.pdf(x, loc=mu, scale=sigma / np.sqrt(sample_size))
plt.plot(x, pdf, 'r--', label='Theoretical Normal (CLT)')

# Plot settings
plt.title(f'Central Limit Theorem Verification\n(Normal Distribution → Sample Means)')
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.axvline(np.mean(sample_means), color='green', linestyle='--', label='Mean of Sample Means')
plt.legend()
plt.show()

# %% [markdown]
# **Q12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Calculates and plots the standard normal distribution (mean=0, std=1).
    """
    # Define the range for the x-axis
    x = np.linspace(-4, 4, 1000)

    # Calculate the standard normal PDF
    pdf = norm.pdf(x, loc=0, scale=1)

    # Plot the PDF
    plt.plot(x, pdf, color='blue', label='Standard Normal PDF')
    plt.title('Standard Normal Distribution (μ = 0, σ = 1)')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.axvline(0, color='red', linestyle='--', label='Mean (Z = 0)')
    plt.legend()
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %% [markdown]
# **Q13.Generate random variables and calculate their corresponding probabilities using the binomial distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters for the binomial distribution
n = 10      # number of trials
p = 0.5     # probability of success
size = 1000  # number of random samples

# Step 1: Generate random variables
samples = np.random.binomial(n=n, p=p, size=size)

# Step 2: Count occurrences of each outcome
values, counts = np.unique(samples, return_counts=True)

# Step 3: Calculate theoretical probabilities (PMF)
pmf_values = binom.pmf(values, n=n, p=p)

# Step 4: Plot observed frequencies vs theoretical probabilities
plt.bar(values, counts / size, width=0.6, label='Empirical Probability', alpha=0.6, color='skyblue', edgecolor='black')
plt.plot(values, pmf_values, 'ro-', label='Theoretical PMF', linewidth=2)

# Plot settings
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# Optional: Print sample and probabilities
for v, p_theory in zip(values, pmf_values):
    print(f"Successes: {v}, Theoretical P(X={v}): {p_theory:.4f}")
# Out:
# Successes: 1, Theoretical P(X=1): 0.0098
# Successes: 2, Theoretical P(X=2): 0.0439
# Successes: 3, Theoretical P(X=3): 0.1172
# Successes: 4, Theoretical P(X=4): 0.2051
# Successes: 5, Theoretical P(X=5): 0.2461
# Successes: 6, Theoretical P(X=6): 0.2051
# Successes: 7, Theoretical P(X=7): 0.1172
# Successes: 8, Theoretical P(X=8): 0.0439
# Successes: 9, Theoretical P(X=9): 0.0098

# %% [markdown]
# **Q14.Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std):
    """
    Calculate the Z-score for a data point.

    Parameters:
        x (float): Data point
        mean (float): Mean of the distribution
        std (float): Standard deviation of the distribution

    Returns:
        float: Z-score
    """
    return (x - mean) / std

def plot_z_score_comparison(z):
    """
    Plot standard normal distribution and mark the Z-score.

    Parameters:
        z (float): Z-score to compare
    """
    x = np.linspace(-4, 4, 1000)
    y = norm.pdf(x)

    # Plot standard normal curve
    plt.plot(x, y, label='Standard Normal Distribution', color='blue')

    # Fill area under curve up to z
    x_fill = np.linspace(-4, z, 1000)
    y_fill = norm.pdf(x_fill)
    plt.fill_between(x_fill, y_fill, alpha=0.5, color='skyblue', label=f'Area ≤ Z ({z:.2f})')

    # Draw vertical line at Z
    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')

    # Labels and styling
    plt.title('Z-score on Standard Normal Distribution')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.show()

# Example usage
x = 75        # data point
mean = 70     # population mean
std = 10      # population standard deviation

z_score = calculate_z_score(x, mean, std)
print(f"Z-score for x = {x}: {z_score:.2f}")
plot_z_score_comparison(z_score)
# Out:
# Z-score for x = 75: 0.50

# %% [markdown]
# **Q15.Implement hypothesis testing using Z-statistics for a sample dataset.**

# %%
import numpy as np
from scipy.stats import norm

# Given data
mu_0 = 500         # Claimed population mean
sample_mean = 490  # Sample mean
sigma = 20         # Known population standard deviation
n = 50             # Sample size
alpha = 0.05       # Significance level (for two-tailed test)

# Step 1: Calculate the Z-statistic
z = (sample_mean - mu_0) / (sigma / np.sqrt(n))

# Step 2: Calculate the critical Z-value for two-tailed test
z_critical = norm.ppf(1 - alpha / 2)

# Step 3: Calculate the p-value
p_value = 2 * (1 - norm.cdf(abs(z)))

# Step 4: Make decision
print(f"Z-statistic: {z:.2f}")
print(f"Z-critical (two-tailed, alpha={alpha}): ±{z_critical:.2f}")
print(f"P-value: {p_value:.4f}")

if abs(z) > z_critical:
    print("Result: Reject the null hypothesis (significant difference).")
else:
    print("Result: Fail to reject the null hypothesis (no significant difference).")
# Out:
# Z-statistic: -3.54
# Z-critical (two-tailed, alpha=0.05): ±1.96
# P-value: 0.0004
# Result: Reject the null hypothesis (significant difference).

# %% [markdown]
# **Q16. Create a confidence interval for a dataset using Python and interpret the result.**

# %%
import numpy as np
from scipy import stats

# Sample dataset (example)
data = [52, 55, 60, 48, 58, 54, 57, 53, 50, 56]

# Step 1: Calculate statistics
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # sample standard deviation (ddof=1)
n = len(data)
confidence_level = 0.95
alpha = 1 - confidence_level

# Step 2: Calculate margin of error using t-distribution
t_critical = stats.t.ppf(1 - alpha/2, df=n-1)
margin_of_error = t_critical * (sample_std / np.sqrt(n))

# Step 3: Compute confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Print result
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 54.30
# 95% Confidence Interval: (51.67, 56.93)

# %% [markdown]
# **Q17.Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.**

# %%
import numpy as np
from scipy import stats

# Step 1: Generate data from a normal distribution
np.random.seed(42)  # For reproducibility
mu = 100            # True population mean
sigma = 15          # True population standard deviation
n = 50              # Sample size

data = np.random.normal(loc=mu, scale=sigma, size=n)

# Step 2: Calculate sample mean and standard deviation
sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # ddof=1 for sample std dev

# Step 3: Set confidence level and calculate margin of error
confidence_level = 0.95
alpha = 1 - confidence_level
t_critical = stats.t.ppf(1 - alpha / 2, df=n - 1)
margin_of_error = t_critical * (sample_std / np.sqrt(n))

# Step 4: Confidence interval
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Step 5: Print results
print(f"Sample Mean: {sample_mean:.2f}")
print(f"95% Confidence Interval: ({ci_lower:.2f}, {ci_upper:.2f})")
# Out:
# Sample Mean: 96.62
# 95% Confidence Interval: (92.64, 100.60)

# %% [markdown]
# **Q18. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters of the normal distribution
mu = 100     # mean
sigma = 15   # standard deviation

# Generate x values
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)

# Calculate the PDF
pdf = norm.pdf(x, loc=mu, scale=sigma)

# Plot the PDF
plt.plot(x, pdf, color='blue', label=f'N({mu}, {sigma}²)')
plt.title('Normal Distribution PDF')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.axvline(mu, color='red', linestyle='--', label='Mean (μ)')
plt.legend()
plt.show()

# %% [markdown]
# **Q19.Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters for the Poisson distribution
λ = 4  # Average rate (mean)
x_values = np.arange(0, 15)  # Range of x-values

# Calculate the CDF
cdf_values = poisson.cdf(x_values, mu=λ)

# Plot the CDF
plt.step(x_values, cdf_values, where='post', color='blue', label='Poisson CDF')
plt.scatter(x_values, cdf_values, color='red')  # Show discrete points
plt.title(f'Poisson Distribution CDF (λ = {λ})')
plt.xlabel('Number of Events (x)')
plt.ylabel('Cumulative Probability')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.show()

# Example interpretation
x_point = 5
prob = poisson.cdf(x_point, mu=λ)
print(f"P(X ≤ {x_point}) = {prob:.4f}")
# Out:
# P(X ≤ 5) = 0.7851

# %% [markdown]
# **Q20. Simulate a random variable using a continuous uniform distribution and calculate its expected value.**

# %%
import numpy as np

# Parameters for the continuous uniform distribution
a = 10   # lower bound
b = 20   # upper bound
n = 10000  # number of samples

# Step 1: Simulate random variables
samples = np.random.uniform(low=a, high=b, size=n)

# Step 2: Calculate expected value
# Theoretical expected value
expected_theoretical = (a + b) / 2

# Empirical (sample) expected value
expected_empirical = np.mean(samples)

# Output results
print(f"Theoretical Expected Value: {expected_theoretical:.2f}")
print(f"Empirical Expected Value (from {n} samples): {expected_empirical:.2f}")
# Out:
# Theoretical Expected Value: 15.00
# Empirical Expected Value (from 10000 samples): 14.94

# %% [markdown]
# **Q21.Write a Python program to compare the standard deviations of two datasets and visualize the difference.**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Example datasets (you can replace these with your own data)
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=500)   # Dataset 1 with std dev ~5
data2 = np.random.normal(loc=50, scale=15, size=500)  # Dataset 2 with std dev ~15

# Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

# Plot histograms side-by-side
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

axes[0].hist(data1, bins=30, color='skyblue', edgecolor='black')
axes[0].set_title(f'Dataset 1\nStd Dev = {std1:.2f}')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Frequency')

axes[1].hist(data2, bins=30, color='salmon', edgecolor='black')
axes[1].set_title(f'Dataset 2\nStd Dev = {std2:.2f}')
axes[1].set_xlabel('Value')

plt.suptitle('Comparison of Standard Deviations Between Two Datasets')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# **Q22. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.**

# %%
import numpy as np

# Generate data from a normal distribution
np.random.seed(123)
data = np.random.normal(loc=50, scale=10, size=1000)

# Calculate range
data_range = np.max(data) - np.min(data)

# Calculate IQR
q75, q25 = np.percentile(data, [75, 25])
iqr = q75 - q25

# Output results
print(f"Range of the dataset: {data_range:.2f}")
print(f"Interquartile Range (IQR) of the dataset: {iqr:.2f}")
# Out:
# Range of the dataset: 68.03
# Interquartile Range (IQR) of the dataset: 13.53

# %% [markdown]
# **Q23.Implement Z-score normalization on a dataset and visualize its transformation.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Step 1: Generate a sample dataset (normal but arbitrary mean/std)
np.random.seed(0)
data = np.random.normal(loc=50, scale=10, size=1000)

# Step 2: Apply Z-score normalization
data_normalized = zscore(data)

# Step 3: Plot original and normalized data
fig, axes = plt.subplots(1, 2, figsize=(12, 5), sharey=True)

# Original data histogram
axes[0].hist(data, bins=30, color='skyblue', edgecolor='black')
axes[0].set_title('Original Data')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Frequency')

# Normalized data histogram
axes[1].hist(data_normalized, bins=30, color='salmon', edgecolor='black')
axes[1].set_title('Z-score Normalized Data')
axes[1].set_xlabel('Z-score')

plt.suptitle('Effect of Z-score Normalization')
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# Optional: Print mean and std before and after normalization
print(f"Original Data Mean: {np.mean(data):.2f}, Std Dev: {np.std(data):.2f}")
print(f"Normalized Data Mean: {np.mean(data_normalized):.2f}, Std Dev: {np.std(data_normalized):.2f}")
# Out:
# Original Data Mean: 49.55, Std Dev: 9.87
# Normalized Data Mean: 0.00, Std Dev: 1.00

# %% [markdown]
# Q24.Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

# %%
import numpy as np
from scipy.stats import skew, kurtosis

def calc_skewness_kurtosis(data=None, n=1000, mu=0, sigma=1):
    """
    Calculate skewness and kurtosis of a dataset.
    If no data provided, generate normal data with given parameters.

    Parameters:
    - data: array-like, optional. Dataset to analyze.
    - n: int, sample size if data is None.
    - mu: float, mean of normal distribution if data is None.
    - sigma: float, std dev of normal distribution if data is None.

    Returns:
    - skewness: float
    - kurtosis_val: float (excess kurtosis; 0 for normal distribution)
    """
    if data is None:
        np.random.seed(42)
        data = np.random.normal(loc=mu, scale=sigma, size=n)

    skewness = skew(data)
    kurtosis_val = kurtosis(data)  # excess kurtosis (normal dist = 0)

    print(f"Skewness: {skewness:.4f}")
    print(f"Kurtosis (excess): {kurtosis_val:.4f}")

    return skewness, kurtosis_val

# Example usage
calc_skewness_kurtosis()
# Out:
# Skewness: 0.1168
# Kurtosis (excess): 0.0662
# (np.float64(0.11680083110533511), np.float64(0.06620589292148393))
